# %%
import sys, os, time
import numpy as np
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib tk
import matplotlib.pyplot as plt

import tnt_util as util
from tnt_util import adict, idict, xset, collate, load, render_dict, get_object, save, Logger, seq_iterate
from tnt_setup import init_gamestate, setup_phase
from tnt_cards import load_card_decks, draw_cards
from collections import namedtuple
import random
from itertools import chain, product
from tnt_units import load_unit_rules
import tnt_setup as setup

from flask_app import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ping()
# Out:
# 'Backend active: use "init" to init game'

# %%
player = 'Axis'

# %%
out = format_msg_to_python(init_game(debug=False, player=player))
# Out:
# Beginning phase: Setup

# %%
player = 'West'

# %%
player = 'USSR'

# %%
player
# Out:
# 'USSR'

# %%
out = format_msg_to_python(get_status(player))

# %%
if 'log' in out:
    print(out.log)
# Out:
# USSR draws 6 action cards (now holding 6 cards)
# Beginning phase: New_Year
# Start of 1936
# Axis draws a peace dividend
# USSR draws a peace dividend
# - you receive 0 victory points
# West draws a peace dividend
# Turn order: USSR, West, Axis
# Beginning phase: Production

# %%
render_dict(out)
# Out:
# <div id="0bee20b8-6bda-4543-8695-f34fc942d5db" style="height: 600px; width:100%;"></div>

# %%
actions = list(util.decode_actions(out.actions))
actions
# Out:
# [('USSR', 'Leningrad', 'Fleet'),
#  ('USSR', 'Stalingrad', 'AirForce'),
#  ('USSR', 'Gorky', 'Infantry'),
#  ('USSR', 'Turkmenistan', 'AirForce'),
#  (154,),
#  ('USSR', 'Penza', 'Infantry'),
#  ('USSR', 'Perm', 'AirForce'),
#  ('USSR', 'Kazakhstan', 'Infantry'),
#  ('USSR', 'Murmansk', 'Submarine'),
#  ('USSR', 'Baku', 'AirForce'),
#  ('USSR', 'Voronezh', 'Tank'),
#  ('USSR', 'Ufa', 'Fortress'),
#  ('USSR', 'Penza', 'AirForce'),
#  ('USSR', 'Kazakhstan', 'AirForce'),
#  ('USSR', 'Turkmenistan', 'Infantry'),
#  ('USSR', 'Leningrad', 'AirForce'),
#  ('USSR', 'Urals', 'Tank'),
#  ('USSR', 'Odessa', 'Tank'),
#  ('USSR', 'Baku', 'Tank'),
#  ('USSR', 'Grozny', 'Carrier'),
#  ('USSR', 'Vologda', 'Tank'),
#  ('USSR', 'Stalingrad', 'Tank'),
#  ('USSR', 'Perm', 'Fortress'),
#  ('USSR', 'Kiev', 'Infantry'),
#  ('USSR', 'Kazakhstan', 'Carrier'),
#  ('USSR', 'Gorky', 'Fortress'),
#  (155,),
#  ('USSR', 'Odessa', 'AirForce'),
#  ('USSR', 'Perm', 'Tank'),
#  ('USSR', 'Archangel', 'Carrier'),
#  ('USSR', 'Urals', 'AirForce'),
#  ('USSR', 'Stalingrad', 'Fortress'),
#  ('USSR', 'Murmansk', 'Infantry'),
#  ('USSR', 'Sevastopol', 'Carrier'),
#  ('USSR', 'Urals', 'Fortress'),
#  ('USSR', 'Vologda', 'Fortress'),
#  ('USSR', 'Georgia', 'Carrier'),
#  ('USSR', 'Baku', 'Fortress'),
#  ('USSR', 'Odessa', 'Fleet'),
#  ('USSR', 'Voronezh', 'Infantry'),
#  ('USSR', 'Kharkov', 'AirForce'),
#  ('USSR', 'Baku', 'Fleet'),
#  ('USSR', 'Odessa', 'Fortress'),
#  ('USSR', 'Kuban', 'AirForce'),
#  ('USSR', 'Archangel', 'Infantry'),
#  ('USSR', 'Kharkov', 'Fleet'),
#  ('USSR', 'Ufa', 'Tank'),
#  ('USSR', 'Bryansk', 'Infantry'),
#  (156,),
#  ('USSR', 'Murmansk', 'Carrier'),
#  ('USSR', 'Turkmenistan', 'Carrier'),
#  ('USSR', 'Moscow', 'Infantry'),
#  ('USSR', 'Ufa', 'AirForce'),
#  ('USSR', 'Grozny', 'Infantry'),
#  (148,),
#  ('USSR', 'Grozny', 'Submarine'),
#  ('USSR', 'Kuban', 'Tank'),
#  ('USSR', 'Gorky', 'Tank'),
#  ('USSR', 'Kharkov', 'Fortress'),
#  ('USSR', 'Kazakhstan', 'Submarine'),
#  (157,),
#  ('USSR', 'Georgia', 'Infantry'),
#  ('USSR', 'Kuban', 'Carrier'),
#  ('USSR', 'Baku', 'Submarine'),
#  ('USSR', 'Odessa', 'Submarine'),
#  ('USSR', 'Kiev', 'Tank'),
#  (149,),
#  ('USSR', 'Leningrad', 'Carrier'),
#  ('USSR', 'Bryansk', 'AirForce'),
#  ('USSR', 'Vologda', 'AirForce'),
#  ('USSR', 'Voronezh', 'Fortress'),
#  ('USSR', 'Moscow', 'Tank'),
#  ('USSR', 'Vologda', 'Infantry'),
#  ('USSR', 'Sevastopol', 'Infantry'),
#  ('USSR', 'Murmansk', 'Tank'),
#  ('USSR', 'Archangel', 'AirForce'),
#  ('USSR', 'Belorussia', 'Infantry'),
#  ('USSR', 'Kuban', 'Infantry'),
#  ('USSR', 'Archangel', 'Fleet'),
#  ('USSR', 'Ufa', 'Carrier'),
#  ('USSR', 'Voronezh', 'AirForce'),
#  ('USSR', 'Kharkov', 'Infantry'),
#  (158,),
#  ('USSR', 'Turkmenistan', 'Submarine'),
#  ('USSR', 'Western_Siberia', 'Fortress'),
#  ('USSR', 'Belorussia', 'AirForce'),
#  ('USSR', 'Leningrad', 'Tank'),
#  ('USSR', 'Sevastopol', 'AirForce'),
#  ('USSR', 'Georgia', 'Tank'),
#  (150,),
#  ('USSR', 'Bryansk', 'Tank'),
#  ('USSR', 'Grozny', 'Fleet'),
#  ('USSR', 'Kharkov', 'Submarine'),
#  ('USSR', 'Grozny', 'Fortress'),
#  ('USSR', 'Sevastopol', 'Tank'),
#  ('USSR', 'Belorussia', 'Tank'),
#  ('USSR', 'Penza', 'Fortress'),
#  ('USSR', 'Kazakhstan', 'Fortress'),
#  ('USSR', 'Archangel', 'Tank'),
#  ('USSR', 'Penza', 'Tank'),
#  ('USSR', 'Kazakhstan', 'Tank'),
#  ('USSR', 'Ufa', 'Infantry'),
#  ('USSR', 'Archangel', 'Fortress'),
#  ('USSR', 'Georgia', 'AirForce'),
#  ('USSR', 'Sevastopol', 'Fortress'),
#  ('USSR', 'Bryansk', 'Fortress'),
#  ('USSR', 'Belorussia', 'Fortress'),
#  (159,),
#  ('USSR', 'Leningrad', 'Infantry'),
#  ('USSR', 'Kuban', 'Submarine'),
#  ('USSR', 'Murmansk', 'AirForce'),
#  ('USSR', 'Baku', 'Carrier'),
#  ('USSR', 'Odessa', 'Carrier'),
#  ('USSR', 'Georgia', 'Fleet'),
#  ('USSR', 'Georgia', 'Fortress'),
#  ('USSR', 'Leningrad', 'Submarine'),
#  ('investment_card',),
#  (151,),
#  ('USSR', 'Turkmenistan', 'Tank'),
#  ('USSR', 'Kiev', 'AirForce'),
#  ('USSR', 'Western_Siberia', 'Tank'),
#  ('USSR', 'Kazakhstan', 'Fleet'),
#  ('USSR', 'Grozny', 'AirForce'),
#  (152,),
#  ('USSR', 'Moscow', 'AirForce'),
#  ('USSR', 'Stalingrad', 'Infantry'),
#  ('USSR', 'Murmansk', 'Fortress'),
#  ('USSR', 'Ufa', 'Submarine'),
#  ('USSR', 'Sevastopol', 'Fleet'),
#  ('USSR', 'Turkmenistan', 'Fleet'),
#  ('USSR', 'Turkmenistan', 'Fortress'),
#  ('action_card',),
#  ('USSR', 'Kuban', 'Fleet'),
#  ('USSR', 'Perm', 'Infantry'),
#  ('USSR', 'Western_Siberia', 'Infantry'),
#  ('USSR', 'Kharkov', 'Carrier'),
#  ('USSR', 'Gorky', 'AirForce'),
#  ('USSR', 'Murmansk', 'Fleet'),
#  (153,),
#  ('USSR', 'Western_Siberia', 'AirForce'),
#  ('USSR', 'Archangel', 'Submarine'),
#  ('USSR', 'Urals', 'Infantry'),
#  ('USSR', 'Kuban', 'Fortress'),
#  ('USSR', 'Odessa', 'Infantry'),
#  ('USSR', 'Kharkov', 'Tank'),
#  ('USSR', 'Ufa', 'Fleet'),
#  ('USSR', 'Baku', 'Infantry'),
#  ('USSR', 'Sevastopol', 'Submarine'),
#  ('USSR', 'Grozny', 'Tank'),
#  ('USSR', 'Georgia', 'Submarine'),
#  ('USSR', 'Leningrad', 'Fortress')]

# %%
# action = random.choice(actions)
# action

# %%
#out = take_action(player, action)

# %%
#out = format_msg_to_python(take_action(player, ('Britain', 'Paris', 'Infantry')))

# %%
for player in ['Axis', 'West', 'USSR']:
    out = format_msg_to_python(get_status(player))
    for _ in range(25):
        if 'error' in out:
            print(out.error)
            break
        elif 'actions' not in out:
            #render_dict(out)
            print('Player {} is waiting'.format(player))
            break
        action = random.choice(list(util.decode_actions(out.actions)))
        print(action)
        out = format_msg_to_python(take_action(player, action))
# Out:
# ('Germany', 'Konigsberg', 'Submarine')
# ('Germany', 'Konigsberg', 'Carrier')
# ('Italy', 'Tripoli', 'Tank')
# ('Germany', 'Berlin', 'Submarine')
# ('Italy', 'Rome', 'Carrier')
# ('Germany', 'Munich', 'AirForce')
# ('Italy', 'Milan', 'Infantry')
# ('Italy', 'Rome', 'Submarine')
# ('Germany', 'Berlin', 'Submarine')
# ('Italy', 'Tripoli', 'Infantry')
# ('Italy', 'Milan', 'Fortress')
# ('Italy', 'Rome', 'Submarine')
# ('Germany', 'Berlin', 'Fortress')
# ('Germany', 'Ruhr', 'Submarine')
# ('Germany', 'Berlin', 'AirForce')
# ('Germany', 'Berlin', 'AirForce')
# ('Germany', 'Berlin', 'Fleet')
# ('Germany', 'Munich', 'AirForce')
# ('Germany', 'Ruhr', 'Tank')
# ('Germany', 'Ruhr', 'Submarine')
# ('Germany', 'Ruhr', 'Carrier')
# ('Italy', 'Rome', 'Fleet')
# Player Axis is waiting
# ('France', 'Paris', 'Fleet')
# ('France', 'Paris', 'Tank')
# ('France', 'Marseille', 'Fortress')
# ('Britain', 'Delhi', 'Fortress')
# ('Britain', 'Glasgow', 'Submarine')
# ('Britain', 'Bombay', 'AirForce')
# ('France', 'Algiers', 'Submarine')
# ('Britain', 'Suez', 'Carrier')
# ('Britain', 'London', 'AirForce')
# ('Britain', 'Delhi', 'Fleet')
# ('Britain', 'London', 'Fleet')
# ('Britain', 'London', 'Infantry')
# Player West is waiting
# ('USSR', 'Kharkov', 'AirForce')
# ('USSR', 'Urals', 'Tank')
# ('USSR', 'Leningrad', 'Fleet')
# ('USSR', 'Stalingrad', 'Tank')
# ('USSR', 'Odessa', 'Fleet')
# ('USSR', 'Baku', 'AirForce')
# ('USSR', 'Leningrad', 'Carrier')
# ('USSR', 'Moscow', 'AirForce')
# ('USSR', 'Kiev', 'Fortress')
# ('USSR', 'Baku', 'AirForce')
# ('USSR', 'Moscow', 'Infantry')
# ('USSR', 'Moscow', 'Fortress')
# ('USSR', 'Baku', 'Fortress')
# Traceback (most recent call last):
#   File "C:\D\a00\js\my\_tnt\all_testClone\tnt\passive_backend.py", line 155, in step
#     possible_actions = phase(G, player, WAITING[player].actions, action) # already factorized
# TypeError: 'NoneType' object is not callable

# %%
G = get_G()
render_dict(G)
# Out:
# <div id="c22075b1-5af9-48da-993e-7b14b460c1f6" style="height: 600px; width:100%;"></div>

# %%
W = get_waiting_actions()
render_dict(W)
# Out:
# <div id="47ab2aff-1490-44c3-8be6-c262972804f2" style="height: 600px; width:100%;"></div>

# %%
for o in seq_iterate(G.players, [None, 'homeland', None], end=True):
    print(o)
# Out:
# ('Axis', 'Germany', {'Munich', 'Berlin', 'Ruhr', 'Konigsberg'})
# ('Axis', 'Italy', {'Milan', 'Sardinia', 'Venice', 'Sicily', 'Rome', 'Taranto'})
# ('USSR', 'USSR', {'Murmansk', 'Voronezh', 'Turkmenistan', 'Ufa', 'Penza', 'Kazakhstan', 'Belorussia', 'Vologda', 'Sevastopol', 'Urals', 'Perm', 'Moscow', 'Stalingrad', 'Georgia', 'Leningrad', 'Kuban', 'Bryansk', 'Odessa', 'Grozny', 'Gorky', 'Kharkov', 'Archangel', 'Baku', 'Western_Siberia', 'Kiev'})
# ('West', 'Britain', {'Glasgow', 'London'})
# ('West', 'France', {'Paris', 'Marseille', 'Lorraine', 'Gascony'})

# %%
path = save('setup_complete.pkl')
path
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-96b061a3b59e> in <module>()
# ----> 1 path = save('setup_complete.pkl')
#       2 path
#
# /mnt/c/Users/anwan/OneDrive - UW Office 365/Khan/Other/tnt/flask_app.py in save(filename)
#      94 @app.route('/save/<filename>')
#      95 def save(filename=None):
# ---> 96         return save_gamestate(filename)
#      97
#      98 @app.route('/load/<data>')
#
# /mnt/c/Users/anwan/OneDrive - UW Office 365/Khan/Other/tnt/passive_backend.py in save_gamestate(filename)
#     189                 return pickle.dumps(data)
#     190         path = os.path.join('saves', filename)
# --> 191         pickle.dump(data, open(path, 'w'))
#     192         return path
#     193
#
# /mnt/c/Users/anwan/OneDrive - UW Office 365/Khan/Other/tnt/structures/arg_dict.py in __getstate__(self)
#      15                 return super().__delitem__(item)
#      16         def __getstate__(self):
# ---> 17                 return super().__getstate__()
#      18         def copy(self):
#      19                 return adict(self.items())
#
# AttributeError: 'super' object has no attribute '__getstate__'

# %%
a = adict()
load_unit_rules(a)
render_dict(a)
# Out:
# <div id="f3627473-71b9-4af3-aafe-dd77c9ef3b6f" style="height: 600px; width:100%;"></div>
